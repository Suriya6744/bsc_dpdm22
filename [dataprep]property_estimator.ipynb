# %% [markdown]
# <a href="https://colab.research.google.com/github/Suriya6744/bsc_dpdm22/blob/main/%5Bdataprep%5Dproperty_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='บ้าน',skiprows=0)
df2 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='ที่ดิน',skiprows=0)
df3 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='คอนโด',skiprows=0)
df4 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='ทาวน์โฮม',skiprows=0)
df5 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='อาคารพาณิชย์',skiprows=0)

# %% [markdown]
# #ข้อมูลประเมินบ้าน

# %%
df1.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# ##ผู้ประเมินคนที่ 1

# %%
ass1 = df1[df1['ID ผู้ประเมิน']==1]
ass1.count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                        100
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# Unnamed: 13                         1
# dtype: int64

# %%
ass1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
ass1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##ผู้ประเมินคนที่ 2

# %%
ass2 = df1[df1['ID ผู้ประเมิน']==2]
ass2.count()
# Out:
# ID ผู้ประเมิน                     90
# post id                           90
# property_type                     90
# ความมั่นใจในการเมินราคาทรัพย์     90
# ราคาทรัพย์                        90
# ประเมินราคาซื้อ-ขาย               89
# ปัจจัยในการประเมินราคาซื้อ-ขาย    89
# เหตุผลไม่มั่นใจราคาประเมิน         1
# ให้คะแนนทรัพย์                    89
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
ass2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %%
ass2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# # เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขายใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ##บ้าน

# %%
ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2.head()
# Out:
# <ipython-input-12-eec33b5e30d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   2700000.0            2700000.0
# ...

# %%
ass2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all1 = ass2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
all1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %%
all1 = all1.dropna(subset=['ราคาทรัพย์','ประเมิน2'])
all1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [89 rows x 4 columns]

# %%
all1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของบ้าน

# %%
actual_h = all1['ราคาทรัพย์']
pred1_h = all1['ประเมิน1']
pred2_h = all1['ประเมิน2']

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mh1 = mean_absolute_percentage_error(actual_h, pred1_h)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mh1*100} %')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 12.321512246130807 %

# %%
mh2 = mean_absolute_percentage_error(actual_h, pred2_h)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mh2*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 10.417687099245775%

# %%
mh3 = mean_absolute_percentage_error(pred1_h, pred2_h)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mh3*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 13.626068116793128%

# %%
mh4 = mean_absolute_percentage_error(pred2_h, pred1_h)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mh4*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 11.582834887783596%

# %%
mh5 = mean_absolute_percentage_error(pred1_h, actual_h)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mh5*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 13.055527046371376%

# %%
mh6 = mean_absolute_percentage_error(pred2_h, actual_h)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mh6*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 8.521474003880796%

# %% [markdown]
# ## ที่ดิน

# %%
df2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
ld1 = df2[df2['ID ผู้ประเมิน']==1]
ld1.count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                        100
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                         10
# Unnamed: 10                        10
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
ld2 = df2[df2['ID ผู้ประเมิน']==2]
ld2.count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                        100
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                         10
# Unnamed: 10                        10
# Unnamed: 11                         0
# Unnamed: 12                         0
# dtype: int64

# %%
ld2['ประเมิน1'] = ld2['post id'].map(ld1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ld2.head()
# Out:
# <ipython-input-29-a0679e8eebb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ld2['ประเมิน1'] = ld2['post id'].map(ld1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                         มั่นใจ     2800000            2000000.0
# ...

# %%
ld2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all2 = ld2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all2
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0   2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0  12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0  70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0  60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0   2500000.0
# ..                                     ...         ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0    750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0   2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0   2800000.0
#
# [100 rows x 4 columns]

# %%
all2.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของที่ดิน

# %%
actual_l = all2['ราคาทรัพย์']
pred1_l = all2['ประเมิน1']
pred2_l = all2['ประเมิน2']

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
ml1 = mean_absolute_percentage_error(actual_l, pred1_l)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {ml1*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 41.33784259452896%

# %%
ml2 = mean_absolute_percentage_error(actual_l, pred2_l)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {ml2*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 40.11878038284342%

# %%
ml3 = mean_absolute_percentage_error(pred1_l, pred2_l)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {ml3*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 74.07933970315449%

# %%
ml4 = mean_absolute_percentage_error(pred2_l, pred1_l)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {ml4*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 42.74775082762699%

# %%
ml5 = mean_absolute_percentage_error(pred1_l, actual_l)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {ml5*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 83.48110682471777%

# %%
ml6 = mean_absolute_percentage_error(pred2_l, actual_l)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {ml6*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 48.37938341613725%

# %% [markdown]
# ## ทาวน์โฮม

# %%
df4
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
th1 = df4[df4['ID ผู้ประเมิน']==1]
th1.count()
# Out:
# ID ผู้ประเมิน                     120
# post id                           120
# property_type                     120
# ความมั่นใจในการเมินราคาทรัพย์     120
# ราคาทรัพย์                        120
# ประเมินราคาซื้อ-ขาย               120
# ปัจจัยในการประเมินราคาซื้อ-ขาย    120
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    120
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
th2 = df4[df4['ID ผู้ประเมิน']==2]
th2.count()
# Out:
# ID ผู้ประเมิน                     120
# post id                           120
# property_type                     120
# ความมั่นใจในการเมินราคาทรัพย์     120
# ราคาทรัพย์                        120
# ประเมินราคาซื้อ-ขาย               120
# ปัจจัยในการประเมินราคาซื้อ-ขาย    120
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    120
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# dtype: int64

# %%
th2['ประเมิน1'] = th2['post id'].map(th1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
th2.head()
# Out:
# <ipython-input-44-e1980f55f3c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th2['ประเมิน1'] = th2['post id'].map(th1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5              2  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7              2  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9              2  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   1045000.0            1500000.0
# ...

# %%
th2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all3 = th2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all3
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %%
all3.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของทาวน์โฮม

# %%
actual_th = all3['ราคาทรัพย์']
pred1_th = all3['ประเมิน1']
pred2_th = all3['ประเมิน2']

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mth1 = mean_absolute_percentage_error(actual_th, pred1_th)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mth1*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 11.373507980201532%

# %%
mth2 = mean_absolute_percentage_error(actual_th, pred2_th)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mth2*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 8.766742521930592%

# %%
mth3 = mean_absolute_percentage_error(pred1_th, pred2_th)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mth3*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 11.21168528826893%

# %%
mth4 = mean_absolute_percentage_error(pred2_th, pred1_th)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mth4*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 10.619748830198178%

# %%
mth5 = mean_absolute_percentage_error(pred1_th, actual_th)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mth5*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 16.209125736159383%

# %%
mth6 = mean_absolute_percentage_error(pred2_th, actual_th)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mth6*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 12.753580848193073%

# %% [markdown]
# # อาคารพาณิชย์

# %%
df5
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
pn1 = df5[df5['ID ผู้ประเมิน']==1]
pn1.count()
# Out:
# ID ผู้ประเมิน                     10
# post id                           10
# property_type                     10
# ความมั่นใจในการเมินราคาทรัพย์     10
# ราคาทรัพย์                        10
# ประเมินราคาซื้อ-ขาย               10
# ปัจจัยในการประเมินราคาซื้อ-ขาย    10
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    10
# Unnamed: 9                        10
# Unnamed: 10                       10
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
pn2 = df5[df5['ID ผู้ประเมิน']==2]
pn2.count()
# Out:
# ID ผู้ประเมิน                     10
# post id                           10
# property_type                     10
# ความมั่นใจในการเมินราคาทรัพย์     10
# ราคาทรัพย์                        10
# ประเมินราคาซื้อ-ขาย               10
# ปัจจัยในการประเมินราคาซื้อ-ขาย    10
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    10
# Unnamed: 9                        10
# Unnamed: 10                       10
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
pn2['ประเมิน1'] = pn2['post id'].map(pn1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
pn2.head()
# Out:
# <ipython-input-59-20aea626f4d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pn2['ประเมิน1'] = pn2['post id'].map(pn1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                             post id          property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5              2  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7              2  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9              2  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
pn2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all4 = pn2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all4
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %%
all4.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของอาคารพาณิชย์

# %%
actual_pn = all4['ราคาทรัพย์']
pred1_pn = all4['ประเมิน1']
pred2_pn = all4['ประเมิน2']

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# - ข้างหน้าคือข้อมูลจริง หลังคือตัวที่ประมาณใกล้เคียง

# %%
mpn1 = mean_absolute_percentage_error(actual_pn, pred1_pn)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mpn1*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 17.643894993894996%

# %%
mpn2 = mean_absolute_percentage_error(actual_pn, pred2_pn)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mpn2*100}%')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 11.732295482295482%

# %%
mpn3 = mean_absolute_percentage_error(pred1_pn, pred2_pn)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mpn3*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 21.58208906103643%

# %%
mpn4 = mean_absolute_percentage_error(pred2_pn, pred1_pn)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mpn4*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 16.97142857142857%

# %%
mpn5 = mean_absolute_percentage_error(pred1_pn, actual_pn)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mpn5*100}%')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 25.4518341307815%

# %%
mpn6 = mean_absolute_percentage_error(pred2_pn, actual_pn)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mpn6*100}%')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 12.428571428571429%

# %% [markdown]
# #Quiz2

# %% [markdown]
# ##เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# #HW2
# แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# ##บ้าน

# %%
all1 = ass2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all1['check1']=all1.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
all1['check2']=all1.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
all1
# Out:
# <ipython-input-75-9b929181f65b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all1['check1']=all1.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-75-9b929181f65b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all1['check2']=all1.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# ...

# %%
all1.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0  3200000.0  2200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0  4200000.0  3000000.0
# ..                                     ...         ...        ...        ...
# 43    https://nayoo.co/khonkaen/posts/1128   4200000.0  4200000.0  5000000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0  1200000.0  1350000.0
# 65    https://nayoo.co/khonkaen/posts/2143   5200000.0  5200000.0  5000000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0  3500000.0  3600000.0
#
#        check1    check2
# ...

# %%
all1.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0  2000000.0  2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0  3500000.0  4000000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0  3300000.0  3200000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0  1500000.0  1200000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0  1700000.0  1800000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 176  https://nayoo.co/khonkaen/posts/18633   5000000.0  4500000.0        NaN
#
#        check1    check2
# ...

# %% [markdown]
# ในคอลัมม์ Check1 และ Check2 ไม่มีค่า value ที่อยู่ประมาณ 10 หมายความว่า ไม่มีข้อมูลที่ผิดพลาด ค่า MAPE มีค่าเท่าเดิม

# %% [markdown]
# ## ที่ดิน

# %%
all2 = ld2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all2['check1']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
all2['check2']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
all2
# Out:
# <ipython-input-78-a5a0c37009ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all2['check1']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-78-a5a0c37009ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all2['check2']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# ...

# %%
all2.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000   4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000  32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   160000000  14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# ..                                     ...         ...         ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000   4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000   1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000   1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000    650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000   2500000.0
#
#        ประเมิน2     check1     check2
# 194  75000000.0  20.000000   1.200000
# 112   2000000.0  12.307692   1.300000
# 58   11000000.0  11.428571  14.545455
# ...

# %%
all2.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 58    https://nayoo.co/khonkaen/posts/9203   160000000  14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550   6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000   2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000   1600000.0
# ..                                     ...         ...         ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000   2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000  10000000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000   2800000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000  12000000.0
#
#        ประเมิน2     check1     check2
# 58   11000000.0  11.428571  14.545455
# 47   18000000.0  10.208333  13.611111
# 148  80000000.0   1.229092  10.848120
# ...

# %% [markdown]
# ### แก้ MAPE ที่มีผลต่างในช่วง 10

# %% [markdown]
# เลือกค่าผลต่างที่อยู่ในช่วง 10 มาแก้ศูนย์ แล้วคิดค่า MAPE ใหม่

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE

df2 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='ที่ดิน',skiprows=0)
ld1 = df2[df2['ID ผู้ประเมิน']==1]
ld1 = ld1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ld2 = df2[df2['ID ผู้ประเมิน']==2]
ld2 = ld2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ld1MAPE = MAPE(ld1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ld1['ราคาทรัพย์']))
ld2MAPE = MAPE(ld2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ld2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {ld1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {ld2MAPE*100:.2f}%')
ld2['ประเมิน2'] = ld2['post id'].map(ld1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
ld2_d = ld2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%

# %% [markdown]
# #### แก้

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE
import numpy as np

df2 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (3).xlsx',sheet_name='ที่ดิน',skiprows=0)
ld1 = df2[df2['ID ผู้ประเมิน']==1]
ld1 = ld1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ld2 = df2[df2['ID ผู้ประเมิน']==2]
ld2 = ld2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ld2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True)
ld2['ประเมิน1'] = ld2['post id'].map(ld1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
all2 = ld2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
all2['check1']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
all2['check2']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)

all2['ประเมิน1'] = np.where(all2['check1'] > 10, all2['ประเมิน1']*10, all2['ประเมิน1'])
all2['ประเมิน2'] = np.where(all2['check2'] > 10, all2['ประเมิน2']*10, all2['ประเมิน2'])

ld1MAPE = MAPE(all2['ประเมิน1'],pd.to_numeric(all2['ราคาทรัพย์']))
ld2MAPE = MAPE(all2['ประเมิน2'],pd.to_numeric(all2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {ld1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {ld2MAPE*100:.2f}%')
all2 = ld2.dropna(subset=['ประเมิน2','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(all2['ประเมิน1'],all2['ประเมิน2'])
two2one = MAPE(all2['ประเมิน2'],all2['ประเมิน1'])
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 46.08%
# นักประเมิน คนที่ 2 = 23.21%
# <ipython-input-82-e3b2490740b8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all2['check1']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-82-e3b2490740b8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all2['check2']=all2.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# ...

# %%
all2.shape
# Out:
# (100, 14)

# %% [markdown]
# ##ทาวน์โฮม
# ไม่มีค่าที่อยู่ประมาณ 10 หมายความว่า ไม่มีข้อมูลที่ผิดพลาด ค่า MAPE มีค่าเท่าเดิม

# %%
all3 = th2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all3['check1']=all3.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
all3['check2']=all3.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
all3
# Out:
# <ipython-input-84-91fd57a8c0c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all3['check1']=all3.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-84-91fd57a8c0c3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all3['check2']=all3.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# ...

# %%
all3.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0  1500000.0  1500000.0
# 132    https://nayoo.co/khonkaen/posts/619   1430000.0   950000.0  1000000.0
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 174   https://nayoo.co/khonkaen/posts/3478   2190000.0  1500000.0  2200000.0
# ..                                     ...         ...        ...        ...
# 228  https://nayoo.co/khonkaen/posts/17923   1990000.0  2000000.0  2200000.0
# 167   https://nayoo.co/khonkaen/posts/2829   2490000.0  2500000.0  2300000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0  2800000.0  2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411   3200000.0  3200000.0  3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503   1500000.0  1500000.0  1300000.0
#
#        check1    check2
# ...

# %%
all3.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 234  https://nayoo.co/khonkaen/posts/18090   3000000.0  2800000.0  1500000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0  1500000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 225  https://nayoo.co/khonkaen/posts/17742   2500000.0  2200000.0  1700000.0
# ..                                     ...         ...        ...        ...
# 188   https://nayoo.co/khonkaen/posts/8101   3200000.0  3300000.0  3200000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0  2800000.0  2800000.0
# 199  https://nayoo.co/khonkaen/posts/12957   1500000.0  1600000.0  1500000.0
# 151   https://nayoo.co/khonkaen/posts/1978   2500000.0  2700000.0  2500000.0
# 181   https://nayoo.co/khonkaen/posts/6104   2200000.0  2500000.0  2200000.0
#
#        check1    check2
# ...

# %% [markdown]
# ในคอลัมม์ Check1 และ Check2 ไม่มีค่า value ที่อยู่ประมาณ 10 หมายความว่า ไม่มีข้อมูลที่ผิดพลาด ค่า MAPE มีค่าเท่าเดิม

# %% [markdown]
# ##อาคารพาณิชย์

# %%
all4 = pn2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all4['check1']=all4.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
all4['check2']=all4.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
all4
# Out:
# <ipython-input-87-425bafa651ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all4['check1']=all4.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-87-425bafa651ad>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all4['check2']=all4.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# ...

# %%
all4.sort_values(by=['check1'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 5   1.666667  1.125000
# 11  1.333333  1.200000
# 15  1.315789  1.000000
# ...

# %%
all4.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 11  1.333333  1.200000
# 1   1.166667  1.142857
# 7   1.142857  1.142857
# ...

# %% [markdown]
# ในคอลัมม์ Check1 และ Check2 ไม่มีค่า value ที่อยู่ประมาณ 10 หมายความว่า ไม่มีข้อมูลที่ผิดพลาด ค่า MAPE มีค่าเท่าเดิม

# %% [markdown]
# # HW3 Visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
import pandas as pd
sheet_id =(f'https://docs.google.com/spreadsheets/d/1jIF55aFmr8rqqK7dBMXoyA71TWlHdIiiQAa0p1Dr794/export?format=xlsx')
land = pd.read_excel(sheet_id,sheet_name='land')
home = pd.read_excel(sheet_id,sheet_name='บ้าน')
townh  = pd.read_excel(sheet_id,sheet_name='ทาวน์โฮม')
pn =  pd.read_excel(sheet_id,sheet_name='อาคารพาณิชย์')

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ## บ้าน

# %%
import numpy as np
import matplotlib.pyplot as plt
pearsoncorr1 = home.corr(method='pearson')
pearsoncorr1
# Out:
#                      ID ผู้ประเมิน  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# ID ผู้ประเมิน             1.000000   -0.001373             0.022823
# ราคาทรัพย์               -0.001373    1.000000             0.834722
# ประเมินราคาซื้อ-ขาย       0.022823    0.834722             1.000000

# %%
import seaborn as sb
sb.heatmap(pearsoncorr1, 
            xticklabels=pearsoncorr1.columns,
            yticklabels=pearsoncorr1.columns,
            cmap='RdBu',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# ## ที่ดิน

# %%
import numpy as np
import matplotlib.pyplot as plt
pearsoncorr2 = land.corr(method='pearson')
pearsoncorr2
# Out:
#                      ID ผู้ประเมิน  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# ID ผู้ประเมิน             1.000000    0.023654             0.047823
# ราคาทรัพย์                0.023654    1.000000             0.759001
# ประเมินราคาซื้อ-ขาย       0.047823    0.759001             1.000000

# %%
import seaborn as sb
sb.heatmap(pearsoncorr2, 
            xticklabels=pearsoncorr2.columns,
            yticklabels=pearsoncorr2.columns,
            cmap='RdBu',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# ## ทาวน์โฮม

# %%
import numpy as np
import matplotlib.pyplot as plt
pearsoncorr3 = townh.corr(method='pearson')
pearsoncorr3=pearsoncorr3.iloc[0:3,0:3]

# %%
import seaborn as sb
sb.heatmap(pearsoncorr3, 
            xticklabels=pearsoncorr3.columns,
            yticklabels=pearsoncorr3.columns,
            cmap='tab20',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# ## อาคารพาณิชย์

# %%
import numpy as np
import matplotlib.pyplot as plt
pearsoncorr4 = pn.corr(method='pearson')
pearsoncorr4
# Out:
#                      ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# ID ผู้ประเมิน         1.000000e+00  5.082630e-18             0.045325
# ราคาทรัพย์            5.082630e-18  1.000000e+00             0.939407
# ประเมินราคาซื้อ-ขาย   4.532517e-02  9.394070e-01             1.000000

# %%
import seaborn as sb
sb.heatmap(pearsoncorr4, 
            xticklabels=pearsoncorr4.columns,
            yticklabels=pearsoncorr4.columns,
            cmap='tab20c',
            annot=True,
            linewidth=0.5)
