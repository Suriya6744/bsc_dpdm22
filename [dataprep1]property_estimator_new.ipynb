# %% [markdown]
# <a href="https://colab.research.google.com/github/Suriya6744/bsc_dpdm22/blob/main/%5Bdataprep1%5Dproperty_estimator_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (2).xlsx',sheet_name='บ้าน',skiprows=0)
df2 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (2).xlsx',sheet_name='ที่ดิน',skiprows=0)
df3 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (2).xlsx',sheet_name='คอนโด',skiprows=0)
df4 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (2).xlsx',sheet_name='ทาวน์โฮม',skiprows=0)
df5 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน (2).xlsx',sheet_name='อาคารพาณิชย์',skiprows=0)

# %% [markdown]
# #ข้อมูลประเมินบ้าน

# %%
df1.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# ##ผู้ประเมินคนที่ 1

# %%
ass1 = df1[df1['ID ผู้ประเมิน']==1]
ass1.count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                         61
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# Unnamed: 13                         1
# dtype: int64

# %%
ass1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  6.100000e+01         1.000000e+02         0.0
# mean             1.0  4.004721e+06         3.938500e+06         NaN
# std              0.0  3.039496e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.500000e+06         2.775000e+06         NaN
# 50%              1.0  3.630000e+06         3.600000e+06         NaN
# 75%              1.0  4.774000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
ass1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##ผู้ประเมินคนที่ 2

# %%
ass2 = df1[df1['ID ผู้ประเมิน']==2]
ass2.count()
# Out:
# ID ผู้ประเมิน                     90
# post id                           90
# property_type                     90
# ความมั่นใจในการเมินราคาทรัพย์     90
# ราคาทรัพย์                        61
# ประเมินราคาซื้อ-ขาย               89
# ปัจจัยในการประเมินราคาซื้อ-ขาย    89
# เหตุผลไม่มั่นใจราคาประเมิน         1
# ให้คะแนนทรัพย์                    89
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
ass2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  6.100000e+01         8.900000e+01         0.0
# mean             2.0  4.004721e+06         4.153258e+06         NaN
# std              0.0  3.039496e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.500000e+06         2.600000e+06         NaN
# 50%              2.0  3.630000e+06         3.900000e+06         NaN
# 75%              2.0  4.774000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %%
ass2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
ass2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# # เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขายใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ##บ้าน

# %%
ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
ass2.head()
# Out:
# <ipython-input-272-eec33b5e30d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ass2['ประเมิน1'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   2700000.0            2700000.0
# ...

# %%
ass2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all1 = ass2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495         NaN  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496         NaN  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
all1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์     True
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %%
all1 = all1.dropna(subset=['ประเมิน2'])
all1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495         NaN  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496         NaN  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [89 rows x 4 columns]

# %%
all1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์     True
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของบ้าน

# %%
actual_h = all1['ราคาทรัพย์']
pred1_h = all1['ประเมิน1']
pred2_h = all1['ประเมิน2']

# %%
mh1 = mape(actual_h, pred1_h)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mh1}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ nan

# %%
mh2 = mape(actual_h, pred2_h)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mh2}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ nan

# %%
mh3 = mape(pred1_h, pred2_h)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mh3}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 13.626068116793128

# %%
mh4 = mape(pred2_h, pred1_h)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mh4}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 11.582834887783596

# %%
mh5 = mape(pred1_h, actual_h)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mh5}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ nan

# %%
mh6 = mape(pred2_h, actual_h)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mh6}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ nan

# %% [markdown]
# ## ทาวน์โฮม

# %%
df4
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
th1 = df4[df4['ID ผู้ประเมิน']==1]
th1.count()
# Out:
# ID ผู้ประเมิน                     120
# post id                           120
# property_type                     120
# ความมั่นใจในการเมินราคาทรัพย์     120
# ราคาทรัพย์                         61
# ประเมินราคาซื้อ-ขาย               120
# ปัจจัยในการประเมินราคาซื้อ-ขาย    120
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    120
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
th2 = df4[df4['ID ผู้ประเมิน']==2]
th2.count()
# Out:
# ID ผู้ประเมิน                     120
# post id                           120
# property_type                     120
# ความมั่นใจในการเมินราคาทรัพย์     120
# ราคาทรัพย์                         61
# ประเมินราคาซื้อ-ขาย               120
# ปัจจัยในการประเมินราคาซื้อ-ขาย    120
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    120
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# dtype: int64

# %%
th2['ประเมิน1'] = th2['post id'].map(th1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
th2.head()
# Out:
# <ipython-input-294-e1980f55f3c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th2['ประเมิน1'] = th2['post id'].map(th1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5              2  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7              2  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9              2  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   1045000.0            1500000.0
# ...

# %%
th2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all2 = th2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all2
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547         NaN  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551         NaN  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434         NaN  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501         NaN  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367         NaN  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %%
all2.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์     True
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
all2 = all2.dropna(subset=['ราคาทรัพย์'])
all2
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3     https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5     https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7     https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9     https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                    ...         ...        ...        ...
# 176  https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 177  https://nayoo.co/khonkaen/posts/3599   1700000.0  1800000.0  1700000.0
# 178  https://nayoo.co/khonkaen/posts/3661   1900000.0  2000000.0  1900000.0
# 179  https://nayoo.co/khonkaen/posts/3719   1550000.0  1400000.0  1500000.0
# 196   https://nayoo.co/khonkaen/posts/616   1540000.0  1500000.0  1500000.0
#
# [61 rows x 4 columns]

# %% [markdown]
# ### MAPE ของทาวน์โฮม

# %%
actual_th = all2['ราคาทรัพย์']
pred1_th = all2['ประเมิน1']
pred2_th = all2['ประเมิน2']

# %%
mth1 = mape(actual_th, pred1_th)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mth1}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 11.827238709553873

# %%
mth2 = mape(actual_th, pred2_th)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mth2}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 9.879763921117188

# %%
mth3 = mape(pred1_th, pred2_th)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mth3}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 12.553213977323969

# %%
mth4 = mape(pred2_th, pred1_th)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mth4}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 10.76360445297477

# %%
mth5 = mape(pred1_th, actual_th)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mth5}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 20.119357796869004

# %%
mth6 = mape(pred2_th, actual_th)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mth6}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 15.838059290617416

# %% [markdown]
# ## อาคารพาณิชย์

# %%
df5
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
pn1 = df5[df5['ID ผู้ประเมิน']==1]
pn1.count()
# Out:
# ID ผู้ประเมิน                     10
# post id                           10
# property_type                     10
# ความมั่นใจในการเมินราคาทรัพย์     10
# ราคาทรัพย์                        10
# ประเมินราคาซื้อ-ขาย               10
# ปัจจัยในการประเมินราคาซื้อ-ขาย    10
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    10
# Unnamed: 9                        10
# Unnamed: 10                       10
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
pn2 = df5[df5['ID ผู้ประเมิน']==2]
pn2.count()
# Out:
# ID ผู้ประเมิน                     10
# post id                           10
# property_type                     10
# ความมั่นใจในการเมินราคาทรัพย์     10
# ราคาทรัพย์                        10
# ประเมินราคาซื้อ-ขาย               10
# ปัจจัยในการประเมินราคาซื้อ-ขาย    10
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    10
# Unnamed: 9                        10
# Unnamed: 10                       10
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
pn2['ประเมิน1'] = pn2['post id'].map(pn1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
pn2.head()
# Out:
# <ipython-input-318-20aea626f4d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pn2['ประเมิน1'] = pn2['post id'].map(pn1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                             post id          property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5              2  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7              2  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9              2  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
pn2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมิน2'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all3 = pn2[['post id', 'ราคาทรัพย์', 'ประเมิน1', 'ประเมิน2']]
all3
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %%
all3.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ### MAPE ของอาคารพาณิชย์

# %%
actual_pn = all3['ราคาทรัพย์']
pred1_pn = all3['ประเมิน1']
pred2_pn = all3['ประเมิน2']

# %%
mpn1 = mape(actual_pn, pred1_pn)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mpn1}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 17.643894993894996

# %%
mpn2 = mape(actual_pn, pred2_pn)
print(f'ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mpn2}')
# Out:
# ราคาทรัพย์เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 11.732295482295482

# %%
mpn3 = mape(pred1_pn, pred2_pn)
print(f'ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ {mpn3}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับผู้ประเมินคนที่ 2 มีค่า MAPE เท่ากับ 21.58208906103643

# %%
mpn4 = mape(pred2_pn, pred1_pn)
print(f'ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ {mpn4}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับผู้ประเมินคนที่ 1 มีค่า MAPE เท่ากับ 16.97142857142857

# %%
mpn5 = mape(pred1_pn, actual_pn)
print(f'ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mpn5}')
# Out:
# ผู้ประเมินคนที่ 1 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 25.4518341307815

# %%
mpn6 = mape(pred2_pn, actual_pn)
print(f'ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ {mpn6}')
# Out:
# ผู้ประเมินคนที่ 2 เทียบกับราคาทรัพย์ มีค่า MAPE เท่ากับ 12.428571428571429
