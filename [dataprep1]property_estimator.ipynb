# %% [markdown]
# <a href="https://colab.research.google.com/github/Suriya6744/bsc_dpdm22/blob/main/%5Bdataprep1%5Dproperty_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df0 = pd.read_excel("/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx",sheet_name = 'บ้าน')
df1= pd.read_excel("/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx",sheet_name = 'ที่ดิน')
df2 = pd.read_excel("/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx",sheet_name = 'คอนโด')
df3 = pd.read_excel("/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx",sheet_name = 'ทาวน์โฮม')
df4 = pd.read_excel("/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx",sheet_name = 'อาคารพาณิชย์')

# %%
df0
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ   2700000.0            2500000.0
# 1                          มั่นใจ   2700000.0            2700000.0
# 2                          มั่นใจ   2600000.0            2200000.0
# 3                          มั่นใจ   2600000.0            2400000.0
# 4                          มั่นใจ   5900000.0            5000000.0
# ..                            ...         ...                  ...
# 185                        มั่นใจ   5500000.0            5000000.0
# 186                        มั่นใจ   7911000.0            7400000.0
# 187                        มั่นใจ   2000000.0            2500000.0
# 188                        มั่นใจ   4000000.0            3900000.0
# 189                        มั่นใจ   1375000.0            1400000.0
#
#                         ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                         5,000-15,000
# 1    โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 2                                         5,000-15,000
# 3     ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 4                                         5,000-15,000
# ..                                                 ...
# 185              ราคาเสนอขาย 20,000-30,000 บาท/ตารางวา
# 186            ราคาเสนอขาย 20,000 - 30,000 บาท/ตารางวา
# 187                   ราคาเสนอขาย 2.2-3.0 ล้านบาท/หลัง
# 188                    ราคาเสนอขาย 3.5-4.0ล้านบาท/หลัง
# 189                   ราคาเสนอขาย 1.2-1.5 ล้านบาท/หลัง
#
#     เหตุผลไม่มั่นใจราคาประเมิน                      ให้คะแนนทรัพย์  \
# 0                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1                          NaN    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 2                          NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 3                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 4                          NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..                         ...                                 ...
# 185                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 186                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 187                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 188                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 189                        NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
#
#      Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0           NaN          NaN          NaN          NaN        100.0
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 185         NaN          NaN          NaN          NaN          NaN
# 186         NaN          NaN          NaN          NaN          NaN
# 187         NaN          NaN          NaN          NaN          NaN
# 188         NaN          NaN          NaN          NaN          NaN
# 189         NaN          NaN          NaN          NaN          NaN
#
# [190 rows x 14 columns]

# %% [markdown]
# # ผู้ประเมินคนที่ 1

# %%
ass1 = df0[df0['ID ผู้ประเมิน']==1]
ass1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                          มั่นใจ   2700000.0            2500000.0
# 2                          มั่นใจ   2600000.0            2200000.0
# 4                          มั่นใจ   5900000.0            5000000.0
# 6                          มั่นใจ   4400000.0            3500000.0
# 8                          มั่นใจ   2750000.0            2500000.0
# ..                            ...         ...                  ...
# 155                        มั่นใจ   5500000.0            4500000.0
# 156                        มั่นใจ   7911000.0            5200000.0
# 157                        มั่นใจ   2000000.0            3600000.0
# 158                        มั่นใจ   4000000.0            4000000.0
# 159                        มั่นใจ   1375000.0            1200000.0
#
#     ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                     5,000-15,000                        NaN
# 2                     5,000-15,000                        NaN
# 4                     5,000-15,000                        NaN
# 6                     5,000-18,000                        NaN
# 8                     5,000-25,000                        NaN
# ..                             ...                        ...
# 155       3,000-30,000 บาท/ตารางวา                        NaN
# 156       3,000-30,000 บาท/ตารางวา                        NaN
# 157       3,000-30,000 บาท/ตารางวา                        NaN
# 158       3,000-35,000 บาท/ตารางวา                        NaN
# 159       3,000-30,000 บาท/ตารางวา                        NaN
#
#                          ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 2    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 4     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 6    2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 8     3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# ..                                  ...         ...          ...          ...
# 155  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 156  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 157  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
# 158   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN          NaN          NaN
# 159  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี         NaN          NaN          NaN
#
#      Unnamed: 12  Unnamed: 13
# 0            NaN        100.0
# 2            NaN          NaN
# 4            NaN          NaN
# 6            NaN          NaN
# 8            NaN          NaN
# ..           ...          ...
# 155          NaN          NaN
# 156          NaN          NaN
# 157          NaN          NaN
# 158          NaN          NaN
# 159          NaN          NaN
#
# [100 rows x 14 columns]

# %% [markdown]
# ## ผลสรุป

# %%
ass1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# 50%            NaN          NaN          NaN        100.0
# 75%            NaN          NaN          NaN        100.0
# max            NaN          NaN          NaN        100.0

# %% [markdown]
# ## ความมั่นใจ-ไม่มั่นใจ

# %%
confid1 = ass1[ass1['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ']
confid1.count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                        100
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# Unnamed: 13                         1
# dtype: int64

# %%
confid1 = ass1[ass1['ความมั่นใจในการเมินราคาทรัพย์']=='ไม่มั่นใจ']
confid1.count()
# Out:
# ID ผู้ประเมิน                     0
# post id                           0
# property_type                     0
# ความมั่นใจในการเมินราคาทรัพย์     0
# ราคาทรัพย์                        0
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        0
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
ass1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ## จำนวนการให้คะแนนทรัพย์

# %%
ass1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# # ผู้ประเมินคนที่ 2

# %%
ass2 = df0[df0['ID ผู้ประเมิน']==2]
ass2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                          มั่นใจ   2700000.0            2700000.0
# 3                          มั่นใจ   2600000.0            2400000.0
# 5                          มั่นใจ   5900000.0            9000000.0
# 7                          มั่นใจ   4400000.0            3700000.0
# 9                          มั่นใจ   2750000.0            2500000.0
# ..                            ...         ...                  ...
# 185                        มั่นใจ   5500000.0            5000000.0
# 186                        มั่นใจ   7911000.0            7400000.0
# 187                        มั่นใจ   2000000.0            2500000.0
# 188                        มั่นใจ   4000000.0            3900000.0
# 189                        มั่นใจ   1375000.0            1400000.0
#
#                         ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1    โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3     ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# 5    โซนนี้ราคาซื้อขาย ประมาณ 10,000-20,000 บาท/ตาร...
# 7               เสนอขาย 3,500,000 - 4,200,000 บาท/หลัง
# 9          ราคาเสนอขาย 2,000,0000 - 2,800,000 บาท/หลัง
# ..                                                 ...
# 185              ราคาเสนอขาย 20,000-30,000 บาท/ตารางวา
# 186            ราคาเสนอขาย 20,000 - 30,000 บาท/ตารางวา
# 187                   ราคาเสนอขาย 2.2-3.0 ล้านบาท/หลัง
# 188                    ราคาเสนอขาย 3.5-4.0ล้านบาท/หลัง
# 189                   ราคาเสนอขาย 1.2-1.5 ล้านบาท/หลัง
#
#     เหตุผลไม่มั่นใจราคาประเมิน                     ให้คะแนนทรัพย์  Unnamed: 9  \
# 1                          NaN   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน         NaN
# 3                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 5                          NaN  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน         NaN
# 7                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 9                          NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# ..                         ...                                ...         ...
# 185                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 186                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 187                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 188                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
# 189                        NaN  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 1            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 5            NaN          NaN          NaN          NaN
# 7            NaN          NaN          NaN          NaN
# 9            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 185          NaN          NaN          NaN          NaN
# 186          NaN          NaN          NaN          NaN
# 187          NaN          NaN          NaN          NaN
# 188          NaN          NaN          NaN          NaN
# 189          NaN          NaN          NaN          NaN
#
# [90 rows x 14 columns]

# %% [markdown]
# ## ผลสรุป

# %%
ass2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# 50%            NaN          NaN          NaN          NaN
# 75%            NaN          NaN          NaN          NaN
# max            NaN          NaN          NaN          NaN

# %% [markdown]
# ## ความมั่นใจ-ไม่มั่นใจ

# %%
confid2 = ass2[ass2['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ']
confid2.count()
# Out:
# ID ผู้ประเมิน                     89
# post id                           89
# property_type                     89
# ความมั่นใจในการเมินราคาทรัพย์     89
# ราคาทรัพย์                        89
# ประเมินราคาซื้อ-ขาย               89
# ปัจจัยในการประเมินราคาซื้อ-ขาย    89
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    89
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
confid2 = ass2[ass2['ความมั่นใจในการเมินราคาทรัพย์']=='ไม่มั่นใจ']
confid2.count()
# Out:
# ID ผู้ประเมิน                     1
# post id                           1
# property_type                     1
# ความมั่นใจในการเมินราคาทรัพย์     1
# ราคาทรัพย์                        1
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        1
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
ass2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ## จำนวนการให้คะแนนทรัพย์

# %%
ass2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# # เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %%
ass2['ID ผู้ประเมิน'] = ass2['post id'].map(ass1.set_index('post id')['ประเมินราคาซื้อ-ขาย']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-c2fe7cfafbcb> in <module>
# ----> 1 ass2['ID ผู้ประเมิน'] = ass2['post id'].map(ass1.set_index('post id'))['ประเมินราคาซื้อ-ขาย']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     824                 # of dtype float64 the return value of this method should
#     825                 # be float64 as well
# --> 826                 mapper = create_series_with_explicit_dtype(
#     827                     mapper, dtype_if_empty=np.float64
#     828                 )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/construction.py in create_series_with_explicit_dtype(data, index, dtype, name, copy, fastpath, dtype_if_empty)
#     830     from pandas.core.series import Series
#     831
# --> 832     if is_empty_data(data) and dtype is None:
#     833         dtype = dtype_if_empty
#     834     return Series(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/construction.py in is_empty_data(data)
#     794     is_none = data is None
#     795     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 796     is_simple_empty = is_list_like_without_dtype and not data
#     797     return is_none or is_simple_empty
#     798
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
all = ass1.merge(ass1,right_on='post id',left_on='post id')
all
# Out:
#     ID ผู้ประเมิน_x                                post id property_type_x  \
# 0                 1     https://nayoo.co/khonkaen/posts/25      บ้านเดี่ยว
# 1                 1     https://nayoo.co/khonkaen/posts/33      บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/495      บ้านเดี่ยว
# 3                 1    https://nayoo.co/khonkaen/posts/564      บ้านเดี่ยว
# 4                 1    https://nayoo.co/khonkaen/posts/566      บ้านเดี่ยว
# ..              ...                                    ...             ...
# 95                1  https://nayoo.co/khonkaen/posts/19495      บ้านเดี่ยว
# 96                1  https://nayoo.co/khonkaen/posts/19496      บ้านเดี่ยว
# 97                1     https://nayoo.co/khonkaen/posts/20      บ้านเดี่ยว
# 98                1     https://nayoo.co/khonkaen/posts/31      บ้านเดี่ยว
# 99                1    https://nayoo.co/khonkaen/posts/570      บ้านเดี่ยว
#
#    ความมั่นใจในการเมินราคาทรัพย์_x  ราคาทรัพย์_x  ประเมินราคาซื้อ-ขาย_x  \
# 0                           มั่นใจ     2700000.0              2500000.0
# 1                           มั่นใจ     2600000.0              2200000.0
# 2                           มั่นใจ     5900000.0              5000000.0
# 3                           มั่นใจ     4400000.0              3500000.0
# 4                           มั่นใจ     2750000.0              2500000.0
# ..                             ...           ...                    ...
# 95                          มั่นใจ     5500000.0              4500000.0
# 96                          มั่นใจ     7911000.0              5200000.0
# 97                          มั่นใจ     2000000.0              3600000.0
# 98                          มั่นใจ     4000000.0              4000000.0
# 99                          มั่นใจ     1375000.0              1200000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย_x เหตุผลไม่มั่นใจราคาประเมิน_x  \
# 0                      5,000-15,000                          NaN
# 1                      5,000-15,000                          NaN
# 2                      5,000-15,000                          NaN
# 3                      5,000-18,000                          NaN
# 4                      5,000-25,000                          NaN
# ..                              ...                          ...
# 95         3,000-30,000 บาท/ตารางวา                          NaN
# 96         3,000-30,000 บาท/ตารางวา                          NaN
# 97         3,000-30,000 บาท/ตารางวา                          NaN
# 98         3,000-35,000 บาท/ตารางวา                          NaN
# 99         3,000-30,000 บาท/ตารางวา                          NaN
#
#                       ให้คะแนนทรัพย์_x  Unnamed: 9_x  ...  ราคาทรัพย์_y  \
# 0    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน           NaN  ...     2700000.0
# 1   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     2600000.0
# 2    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน           NaN  ...     5900000.0
# 3   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     4400000.0
# 4    3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน           NaN  ...     2750000.0
# ..                                 ...           ...  ...           ...
# 95  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     5500000.0
# 96  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     7911000.0
# 97  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     2000000.0
# 98   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน           NaN  ...     4000000.0
# 99  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี           NaN  ...     1375000.0
#
#     ประเมินราคาซื้อ-ขาย_y  ปัจจัยในการประเมินราคาซื้อ-ขาย_y  \
# 0               2500000.0                      5,000-15,000
# 1               2200000.0                      5,000-15,000
# 2               5000000.0                      5,000-15,000
# 3               3500000.0                      5,000-18,000
# 4               2500000.0                      5,000-25,000
# ..                    ...                               ...
# 95              4500000.0          3,000-30,000 บาท/ตารางวา
# 96              5200000.0          3,000-30,000 บาท/ตารางวา
# 97              3600000.0          3,000-30,000 บาท/ตารางวา
# 98              4000000.0          3,000-35,000 บาท/ตารางวา
# 99              1200000.0          3,000-30,000 บาท/ตารางวา
#
#     เหตุผลไม่มั่นใจราคาประเมิน_y                    ให้คะแนนทรัพย์_y  \
# 0                            NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 1                            NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2                            NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 3                            NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4                            NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ..                           ...                                 ...
# 95                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 96                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 97                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 98                           NaN   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 99                           NaN  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
#
#    Unnamed: 9_y Unnamed: 10_y  Unnamed: 11_y  Unnamed: 12_y Unnamed: 13_y
# 0           NaN           NaN            NaN            NaN         100.0
# 1           NaN           NaN            NaN            NaN           NaN
# 2           NaN           NaN            NaN            NaN           NaN
# 3           NaN           NaN            NaN            NaN           NaN
# 4           NaN           NaN            NaN            NaN           NaN
# ..          ...           ...            ...            ...           ...
# 95          NaN           NaN            NaN            NaN           NaN
# 96          NaN           NaN            NaN            NaN           NaN
# 97          NaN           NaN            NaN            NaN           NaN
# 98          NaN           NaN            NaN            NaN           NaN
# 99          NaN           NaN            NaN            NaN           NaN
#
# [100 rows x 27 columns]

# %%
home =
